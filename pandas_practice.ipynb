# %%
import pandas as pd
import numpy as np

abc=pd.read_csv('cars.csv')
abc
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
import pandas as pd
import numpy as np
abc=pd.read_csv('cars.csv', header = None)
abc
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
import pandas as pd
import numpy as np
abc=pd.read_csv('cars.csv', header = None, index_col=1)
abc
# Out:
#          0              2      3      4
# 1
# US    USCA  United States  809.0  False
# AUS  ASPAC      Australia  731.0   True
# JAP  ASPAC          Japan  588.0   True
# IN   ASPAC          India   18.0   True
# RU   ASPAC         Russia  200.0  False
# MOR  LATAM        Morocco   70.0  False
# EG     AFR          Egypt   45.0  False
# ENG    EUR        England    NaN   True

# %%
abc.columns
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
abc.columns=["Region", "Country Code", "Cars per capita", "Drives the car"]

abc
# Out:
#     Region   Country Code  Cars per capita  Drives the car
# 1
# US    USCA  United States            809.0           False
# AUS  ASPAC      Australia            731.0            True
# JAP  ASPAC          Japan            588.0            True
# IN   ASPAC          India             18.0            True
# RU   ASPAC         Russia            200.0           False
# MOR  LATAM        Morocco             70.0           False
# EG     AFR          Egypt             45.0           False
# ENG    EUR        England              NaN            True

# %%
abc.index.name
# Out:
# 1

# %%
del abc.index.name

abc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 del abc.index.name
#       3 abc
#
# AttributeError: property 'name' of 'Index' object has no deleter

# %%
import pandas as pd
import numpy as np
abc=pd.read_csv('cars.csv', header = None, index_col=[0,1])
abc
# Out:
#                        2      3      4
# 0     1
# USCA  US   United States  809.0  False
# ASPAC AUS      Australia  731.0   True
#       JAP          Japan  588.0   True
#       IN           India   18.0   True
#       RU          Russia  200.0  False
# LATAM MOR        Morocco   70.0  False
# AFR   EG           Egypt   45.0  False
# EUR   ENG        England    NaN   True

# %%
abc.columns=[ "Country Code", "Cars per capita", "Drives the car"]

abc
# Out:
#             Country Code  Cars per capita  Drives the car
# 0     1
# USCA  US   United States            809.0           False
# ASPAC AUS      Australia            731.0            True
#       JAP          Japan            588.0            True
#       IN           India             18.0            True
#       RU          Russia            200.0           False
# LATAM MOR        Morocco             70.0           False
# AFR   EG           Egypt             45.0           False
# EUR   ENG        England              NaN            True

# %%
print (abc.index.names)
# Out:
# [0, 1]

# %%
abc.index.names =['Region_code', "Country_code"]

abc
# Out:
#                            Country Code  Cars per capita  Drives the car
# Region_code Country_code
# USCA        US            United States            809.0           False
# ASPAC       AUS               Australia            731.0            True
#             JAP                   Japan            588.0            True
#             IN                    India             18.0            True
#             RU                   Russia            200.0           False
# LATAM       MOR                 Morocco             70.0           False
# AFR         EG                    Egypt             45.0           False
# EUR         ENG                 England              NaN            True

# %%
#now practice with some other data 

# sales from example from upgrd

# %%
import numpy as np
import pandas as pd

sales=pd.read_excel("sales.xlsx")
sales
# Out:
#           Market             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# ...

# %%
sales.tail()
# Out:
#    Market       Region  No_of_Orders    Profit      Sales
# 18   USCA   Western US           490  44303.65  251991.83
# 19   USCA  Southern US           255  19991.83  148771.91
# 20   USCA   Eastern US           443  47462.04  264973.98
# 21   USCA   Central US           356  33697.43  170416.31
# 22   USCA       Canada            49   7246.62   26298.81

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Market        23 non-null     object
#  1   Region        23 non-null     object
#  2   No_of_Orders  23 non-null     int64
#  3   Profit        23 non-null     float64
#  4   Sales         23 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.0+ KB

# %%
sales.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
import matplotlib.pyplot as plt

sales[["Sales","Profit"]].plot(kind='box', subplots=True)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 import matplotlib.pyplot as plt
#       3 sales[["Sales","Profit"]].plot(kind='box', subplots=True)
# ----> 4 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# !pip install panda
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7245 sha256=ea8031f348a44deaf943f7e59f8a092ac248a57168ba0f99ee16750a5db2cbd2
#   Stored in directory: c:\users\anups\appdata\local\pip\cache\wheels\df\5c\39\36f8dae25a1e88d6ec4411dec4a143781e64fdff6897758eec
# Successfully built panda
# ...

# %%
# !pip install numpy

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

sales[["sales","profit"]].plot(kind='box', subplots=True)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 sales[["sales","profit"]].plot(kind='box', subplots=True)
#       4 plot.show()
#
# NameError: name 'sales' is not defined

# %%
sales.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sales.describe()
#
# NameError: name 'sales' is not defined

# %%
import numpy as np
import pandas as pd

sales=pd.read_excel("sales.xlsx")
sales
# Out:
#           Market             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# ...

# %%
sales.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
sales.head()
# Out:
#    Market           Region  No_of_Orders    Profit     Sales
# 0  Africa   Western Africa           251 -12901.51  78476.06
# 1  Africa  Southern Africa            85  11768.58  51319.50
# 2  Africa     North Africa           182  21643.08  86698.89
# 3  Africa   Eastern Africa           110   8013.04  44182.60
# 4  Africa   Central Africa           103  15606.30  61689.99

# %%
sales[["Profit"]]
# Out:
#       Profit
# 0  -12901.51
# 1   11768.58
# 2   21643.08
# 3    8013.04
# 4   15606.30
# 5  -16766.90
# 6   67998.76
# 7   20948.84
# 8   54734.02
# 9   72805.10
# 10  -2649.76
# 11  82091.27
# 12  18911.49
# 13  43237.44
# 14  25050.69
# 15  12377.59
# 16  74679.54
# 17  13529.59
# 18  44303.65
# 19  19991.83
# 20  47462.04
# 21  33697.43
# 22   7246.62

# %%
sales[["Sales","Profit"]].plot(kind='box', subplots=True)
plt.show()
